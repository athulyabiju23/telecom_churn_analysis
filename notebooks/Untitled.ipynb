# %%
import pandas as pd

import os
print(os.getcwd())  # shows where python thinks you are right now
print(os.listdir('data/raw/'))  # shows what files are actually in that folder
# Out:
# /Users/athulya/Desktop/projects/churn
# ['bigml_59c28831336c6604c800002a.csv', '.DS_Store', 'Telecom+Customer+Churn.zip', 'telecom_data_dictionary.csv', 'Telecom+Customer+Churn', 'telecom_zipcode_population.csv', 'archive.zip', 'telecom_customer_churn.csv', 'archive (1).zip', 'WA_Fn-UseC_-Telco-Customer-Churn.csv']

# %%
import pandas as pd

ibm = pd.read_csv('data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
maven = pd.read_csv('data/raw/telecom_customer_churn.csv')

print(ibm['customerID'].head(10))
print()
print(maven['Customer ID'].head(10))
# Out:
# 0    7590-VHVEG
# 1    5575-GNVDE
# 2    3668-QPYBK
# 3    7795-CFOCW
# 4    9237-HQITU
# 5    9305-CDSKC
# 6    1452-KIOVK
# 7    6713-OKOMC
# 8    7892-POOKP
# 9    6388-TABGU
# Name: customerID, dtype: object
#
# 0    0002-ORFBO
# 1    0003-MKNFE
# 2    0004-TLHLJ
# 3    0011-IGKFF
# 4    0013-EXCHZ
# 5    0013-MHZWF
# 6    0013-SMEOE
# 7    0014-BMAQU
# 8    0015-UOCOJ
# 9    0016-QLJIS
# Name: Customer ID, dtype: object

# %%
common = set(ibm['customerID']) & set(maven['Customer ID'])
print(f'Matching IDs: {len(common)}')
print(f'IBM total: {len(ibm)}')
print(f'Maven total: {len(maven)}')
# Out:
# Matching IDs: 7043
# IBM total: 7043
# Maven total: 7043

# %%
kaggle = pd.read_csv('data/raw/bigml_59c28831336c6604c800002a.csv')
print(kaggle.head())
print()
print(kaggle['churn'].value_counts())
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
print(ibm['Churn'].value_counts())
print()
print(ibm['Churn'].value_counts(normalize=True))
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
import os
print(os.getcwd())
print(os.listdir('.'))
# Out:
# /Users/athulya/Desktop/projects/telecom-churn-analysis/notebooks
# ['Untitled.ipynb', '.ipynb_checkpoints']

# %%
import pandas as pd

maven = pd.read_csv('../data/raw/telecom_customer_churn.csv')
maven.to_csv('../data/raw/maven_telco_clean.csv', index=False, encoding='utf-8')
print("done")
# Out:
# done
